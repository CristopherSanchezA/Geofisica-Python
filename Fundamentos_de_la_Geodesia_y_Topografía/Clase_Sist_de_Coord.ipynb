# %% [markdown]
# **Sistema de Coordenadas**

# %% [markdown]
# ¿Qué es una proyección?
# Es pasar la información del globo terraqueo (3D) a un plano (2D)

# %% [markdown]
# Tipos de Proyecciones:
# Existen 3 tipos de proyecciones principales
