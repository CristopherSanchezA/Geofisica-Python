# %% [markdown]
# # Introducción a Python
#
# ## Fundamentos de Geodesia y Topografía - 2026
# #### Fernanda Castro Araya, Fernanda Bonilla Contreras

# %% [markdown]
# ¿Qué hace print()?

# %%
# Esto es un comentario
print("Hola Geofísicas y Geofísicos") # Esto imprimirá un mensaje
# Out:
# Hola Geofísicas y Geofísicos

# %% [markdown]
# **Tipos de datos básicos**
# - Strings o cadenas de textos

# %%
nombre = "Fernanda"
print("Hola,", nombre)
print("Número de letras en el nombre:", len(nombre))

# También se pueden reemplazar los elementos del string
nombre2 = nombre.replace('da', 'do', 1)
print(nombre2)

# también se puede hacer con letras
nombre3 = nombre.replace('a', 'o', 2)
print(nombre3)

# Los strings también pueden ser llamados
nombre4 = '%s ayudante'%nombre # ¿Qué hace %s ?
print('El nombre del archivo es:', nombre4)
# Out:
# Hola, Fernanda
# Número de letras en el nombre: 8
# Fernando
# Fernondo
# El nombre del archivo es: Fernanda ayudante

# %% [markdown]
# - Números: int, float y complex

# %%
entero = 7        
flotante = 3.1415    
complejo = 4 + 2j

# Operaciones matemáticas
print(entero + flotante) # suma
print(entero * complejo) # multiplicación
print(entero/flotante) # división
print(entero**flotante) # potencia

print ('Parte real del número complejo:', complejo.real, '\nParte imaginaria del número complejo:', complejo.imag) #Qué hace \n en el print?
type(flotante)

# Ahora, realizaremos un print de nuestra variable flotante
print('La variable flotante es: %.2f'%flotante)  # ¿Qué pasa si cambiamos el número 2 de .2f por otro número?
# Out:
# 10.1415
# (28+14j)
# 2.228234919624383
# 451.72642097521504
# Parte real del número complejo: 4.0
# Parte imaginaria del número complejo: 2.0
# La variable flotante es: 3.14

# %% [markdown]
# - Booleano (bool)

# %%
# Tenemos la latitud de una estación
latitud = -36.5

# Un booleano puede representar una condición
en_chile = (latitud < -17.5) and (latitud > -56.0)

print("La estación está en Chile?", en_chile)
type(en_chile)
# Out:
# La estación está en Chile? True
# bool

# %% [markdown]
# **Listas**

# %%
nombres = ["Ana", "Luis", "Sofía"]
print(nombres[0])        # primer elemento
print(len(nombres))      # tamaño de la lista

# %%
nombres.append("Juan")   # agregar un nuevo elemento
print(nombres)

# %%
# También se pueden cambiar elementos de la lista
nombres[0] = 'Martina'
print(nombres)

# %% [markdown]
# **Tupla**

# %%
coordenadas = (36.5, -72.0)
print("Latitud:", coordenadas[0])
print("Longitud:", coordenadas[1])

# %%
# Creemos una Tupla y veamos las diferencias entre una lista y una tupla
l = [['Letras:', 'a', 'b', 'c'], ['Números:', '1', '2', '3']] # lista
print('Nuestra lista es:', l)

t = (('Letras:', 'd', 'e', 'f'), ('Números:', '4', '5', '6'))
print('Nuestra tupla es:', t)
# Out:
# Nuestra lista es: [['Letras:', 'a', 'b', 'c'], ['Números:', '1', '2', '3']]
# Nuestra tupla es: (['Letras:', 'd', 'e', 'f'], ['Números:', '4', '5', '6'])

# %%
l[0][1] = "b"
print("La nueva lista es:", l)

t(0)(1) = "c"
print("La nueva tupla es:", t)
# Out:
#   Cell In[8], line 4
#     t(0)(1) = "c"
#     ^
# SyntaxError: cannot assign to function call here. Maybe you meant '==' instead of '='?

# %% [markdown]
# Ahora, cambiemos los valores dentro de nuestra lista y Tupla

# %% [markdown]
# **Diccionarios**

# %%
# Diccionario de una estación GPS
estacion = {
    "id": "GPS001",
    "nombre": "Estación Concepción",
    "lat": -36.82,
    "lon": -73.05,
    "altura": 12.5
}

# Acceder a elementos
print("Nombre:", estacion["nombre"])
print("Latitud:", estacion["lat"])
print("Longitud:", estacion["lon"])

# Si no conozco los elementos de mi diccionario
print('Las llaves de mi diccionario son:\n',estacion.keys())

# Si no conozco el contenido de mi diccionario usamos .values
print('Este es el contenido de las llaves de mi diccionario "estación:"', estacion.values())
# Out:
# Nombre: Estación Concepción
# Latitud: -36.82
# Longitud: -73.05
# Las llaves de mi diccionario son:
#  dict_keys(['id', 'nombre', 'lat', 'lon', 'altura'])
# Este es el contenido de las llaves de mi diccionario "estación:" dict_values(['GPS001', 'Estación Concepción', -36.82, -73.05, 12.5])

# %% [markdown]
# **Operaciones y slicing en listas**

# %%
numeros = [10, 20, 30, 40, 50]
print(numeros[2:5])   # elementos de índice 2 a 4
# Out:
# [30, 40, 50]

# %% [markdown]
# **Condicionales: if, elif y else**

# %%
latitud = -16.5

if latitud < -40:
    print("La estación está en el sur de Chile")
elif latitud < -30:
    print("La estación está en la zona centro-sur")
else:
    print("La estación está en el norte de Chile")

# Se descarta primero el sur, luego el "elif" descarta zona centro-sur y deja el último grupo que corresponde al norte de Chile

# %% [markdown]
# **Ciclos/Loops**
# - for loop

# %%
suma = 0
for i in range(1, 11):
    suma += i
print("La suma de los primeros 10 números es:", suma)
# Out:
# La suma de los primeros 10 números es: 55

# %%
numeros = [3, 7, 12, 5, 9]
suma = 0
for n in numeros:
    suma += n
print("La suma de la lista es:", suma)
# Out:
# La suma de la lista es: 36

# %% [markdown]
# - While loop

# %%
suma = 0
i = 1
while suma < 10:
    suma += i
    print("La suma ahora es:", suma)
    i += 1
# Out:
# La suma ahora es: 1
# La suma ahora es: 3
# La suma ahora es: 6
# La suma ahora es: 10

# %% [markdown]
# - Break y continue

# %%
for i in range(6):
    if i == 4:
        break     # sale del bucle
    if i == 2:
        continue  # salta esta iteración
    print(i)
# Out:
# 0
# 1
# 3

# %% [markdown]
# **Funciones: def**

# %%
# Definir la función
def multiplicar(a, b=2):
    """
    Esta función multiplica dos números.
    Si no se da el segundo número, por defecto se multiplica por 2.
    """
    return a * b

# %%
# Ejemplos de uso
resultado1 = multiplicar(3, 4)   # Multiplica 3 * 4
resultado2 = multiplicar(5)      # Multiplica 5 * 2 (usa el valor por defecto)
resultado3 = multiplicar(a=7, b=6)  # Uso con argumentos nombrados

# Mostrar resultados
print("3 * 4 =", resultado1)
print("5 * 2 =", resultado2)
print("7 * 6 =", resultado3)
# Out:
# 3 * 4 = 12
# 5 * 2 = 10
# 7 * 6 = 42

# %% [markdown]
# Probemos utilizar un booleano con la función multiplicar

# %%
resultadoo = multiplicar(3,3)
if resultadoo <10:
    print("xd")

a = True
if a:
    resultadoo1 = multiplicar(1,1)
    print("El resultado es:", resultadoo1)
else:
    resultadoo2 = multiplicar(10*10)
    print("El resultado es:", resultadoo2)
# Out:
# xd
# El resultado es: 200

# %% [markdown]
# **Librerías**
# - Math

# %%
import math
print(math.sqrt(144))  # Imprime la raíz cuadrada

# %% [markdown]
# - Numpy y matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

# Definimos tiempo 
t = np.arange(0, 60, 0.05)  # 60 segundos con paso de 0.05 s

# Señal simulada: combinación de ondas + decaimiento exponencial
onda1 = np.sin(2 * np.pi * 0.5 * t) * np.exp(-0.02 * t)   # onda de baja frecuencia
onda2 = 0.5 * np.sin(2 * np.pi * 2.0 * t) * np.exp(-0.05 * t)  # onda más rápida
ruido = 0.1 * np.random.randn(len(t))  # ruido aleatorio

# Sismograma sintético (onda1 + onda2 + ruido)
sismograma = onda1 + onda2 + ruido

# Graficar
fig, ax = plt.subplots(figsize=(10, 4))
ax.plot(t, sismograma, color="black", linewidth=1)

# Personalizar
ax.set(
    xlabel="Tiempo (s)",
    ylabel="Amplitud (m/s)",
    title="Ejemplo de sismograma sintético"
)
ax.grid(True)

plt.show()

# %% [markdown]
# - Otras librerías

# %%
import matplotlib.pyplot as plt #para graficar
import numpy as np #numericos (libreria importante)
import pylab as pl #para graficar
import time # Este módulo proporciona varias funciones relacionadas con el tiempo. 
from datetime import datetime, timedelta 
 # datetime (month,day,year,hour,second,microsecond) es una combinación entre la fecha y el tiempo.
 # timedelta es una duración del tiempo
import pickle  # Devuelve el objeto como un objeto de bytes
import pandas as pd # Para leer archivos csv
from scipy import stats # Funciones de correlación, estadistica, probabilidad etc
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 9
#       6  # datetime (month,day,year,hour,second,microsecond) es una combinación entre la fecha y el tiempo.
#       7  # timedelta es una duración del tiempo
#       8 import pickle  # Devuelve el objeto como un objeto de bytes
# ----> 9 import pandas as pd # Para leer archivos csv
#      10 from scipy import stats # Funciones de correlación, estadistica, probabilidad etc
#
# ModuleNotFoundError: No module named 'pandas'

# %% [markdown]
# ## **Desafío: Perfíl de temperatura en la corteza** ##

# %% [markdown]
# En geofísica, la temperatura aumenta con la profundidad debido al gradiente geotérmico. Para saber que temperatura tennemos en determinada profundidad usamos la ecuación,
#
#                                                              T(z)= t0 + gr * z
# siendo t0 la temperatura superficial en °C, gr el gradiente geotermico en °C/Km y z la profundidad en km.
#
# Calcule y grafique el perfil de temperatura de la corteza hasta 50 km de profundidad. Considerando una temperatura superficial de 15°C, el gradiente geotermico típico de 25-30°C/km. Para obtener el perfil defina una función de la forma, temperatura(z, T0, gradiente) que devuelva la temperatura a esa profundidad, graficar el perfil de temperatura (profundidad en el eje Y y temperatura en el eje X).
#
# **Pista:**
# Usar un loop y np.linspace para calcular la temperatura desde 0 hasta 50 km (cada 1km).
#
# Para graficar, plt.plot(T, z) (invirtiendo eje Y con plt.gca().invert_yaxis())
